# %% [markdown]
# # Tasks 3-5

# %% [markdown]
# ### Task 3
# How would you answer the student's question below? Your task is to get your message across in such a way that a beginner can understand your explanation. You can do this any way you want (pictures, GIFs, metaphors, anything) so long as it makes your explanation clear.
# Answer the question: "What is the difference between DataFrame and Series?"
# Indicate how much time you spent completing this task.

# %% [markdown]
# ### Answer
# Series is a one-dimensional data structure that consists of a key-value pair. It's similar to python dictionary, but provides more abilities to manipulate with data
# ![Series%20vs.%20dataframe%20in%20pandas%20-%20Google%20Chrome.jpg](attachment:Series%20vs.%20dataframe%20in%20pandas%20-%20Google%20Chrome.jpg)

# %% [markdown]
# Dataframe is a two-dimensional data-structure that can be thought of as an Excel spreadsheet. Dataframe may contain two or more series.
# ![2Series%20vs.%20dataframe%20in%20pandas%20-%20Google%20Chrome.jpg](attachment:2Series%20vs.%20dataframe%20in%20pandas%20-%20Google%20Chrome.jpg)

# %% [markdown]
# ### Task 4
# You are given two random variables X and Y.
#
# E(X) = 0.5, Var(X) = 2
#
# E(Y) = 7, Var(Y) = 3.5
#
# cov (X, Y) = -0.8
#
# Find the variance of the random variable Z = 2X - 3Y

# %% [markdown]
# ### Answer

# %%
import numpy as np

expectation_x = 0.5 # E(X)
variance_x = 2 # Var(X)

print('E(X) is', expectation_x)
print('Var(X) is', variance_x)
print()


expectation_y = 7 # E(Y)
variance_y = 3.5 # Var(Y)

print('E(Y) is', expectation_y)
print('Var(Y) is', variance_y)
print()

cov_x_y = -0.8 # cov(X, Y)

print('cov(X,Y) is', cov_x_y)
print()



#𝑉𝑎𝑟(𝑍)=𝑉𝑎𝑟(2𝑋−3𝑌)= Var(2X) + Var(3Y) - 2cov(X,Y) = 4Var(X) + 9Var(Y)  - 2cov(X, Y)
print("Finally, find the variance of Z=2X-3Y by formula 𝑉𝑎𝑟(𝑍)=𝑉𝑎𝑟(2𝑋−3𝑌)= Var(2X) + Var(3Y) - 2cov(X,Y) = 4Var(X) + 9Var(Y)  - 2cov(X, Y)")
print('Var(Z) is', 4*variance_x + 9*variance_y - 2*cov_x_y)
# Out:
# E(X) is 0.5
# Var(X) is 2
#
# E(Y) is 7
# Var(Y) is 3.5
#
# cov(X,Y) is -0.8
#
# Finally, find the variance of Z=2X-3Y by formula 𝑉𝑎𝑟(𝑍)=𝑉𝑎𝑟(2𝑋−3𝑌)= Var(2X) + Var(3Y) - 2cov(X,Y) = 4Var(X) + 9Var(Y)  - 2cov(X, Y)
# Var(Z) is 41.1

# %% [markdown]
# ### Task 5
# Omer trained a linear regression model and tested its performance on a test sample of 500
# objects. On 400 of those, the model returned a prediction higher than expected by 0.5, and on
# the remaining 100, the model returned a prediction lower than expected by 0.7.
# What is the MSE for his model?
#
# Limor claims that the linear regression model wasn't trained correctly, and we can do improve
# it by changing all the answers by a constant value. What will be her MSE?
# You can assume that Limor found the smallest error under her constraints.
#
# Return two values - Omer's and Limor's MSE.

# %% [markdown]
# ### Answer

# %%
mse = (400 * 0.5**2 + 100 * 0.7**2)/(500-2)
print("MSE for Omer's model is", round(mse, 3) )

mse_limor = (400 * (0.5-0.25)**2 + 100 * (0.7+0.25)**2)/(500-2)
print("Limor's MSE is", round(mse_limor,3) )
# Out:
# MSE for Omer's model is 0.299
# Limor's MSE is 0.231
